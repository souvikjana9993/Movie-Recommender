# %%
import json
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
from pathlib import Path
PROJECT_ROOT = Path("/home/sjscarface/piprojects/recommendersystem")
DATA_DIR = PROJECT_ROOT / "data"
CANDIDATES_FILE = DATA_DIR / "candidates.json"
WATCH_HISTORY_FILE = DATA_DIR / "watch_history.json"
RECOMMENDATIONS_FILE = DATA_DIR / "recommendations.json"

# %%
def load_data():
    """Load candidates from Phase 1."""
    print("📂 Loading candidates...")

    with open(CANDIDATES_FILE, "r") as f:
        data = json.load(f)

    candidates = data["candidates"]
    print(f"   Loaded {len(candidates)} candidates")

    # Convert to DataFrame for easier manipulation
    candidate_df = pd.DataFrame(candidates)

    return candidate_df

# %%
data = load_data()
# Out:
# 📂 Loading candidates...
#    Loaded 710 candidates

# %%
def _build_feature_text(self, item: dict) -> str:
        """
        Combine all text features into a single string for TF-IDF.
        
        LEARNING NOTE: Feature Engineering
        -----------------------------------
        We concatenate multiple features because:
        1. TF-IDF works on text, so we need a text representation
        2. Repeating important features increases their weight
        3. Different features capture different aspects of similarity
        
        We weight features by repetition:
        - Genres: repeated 3x (very important for similarity)
        - Keywords: repeated 2x (distinctive features)
        - Cast: repeated 1x (actor preferences)
        - Overview: repeated 1x (thematic similarity)
        """
        parts = []
        
        # Genres (weight: 3x) - most important for broad similarity
        genres = item.get("genres", [])
        parts.extend(genres * 3)
        
        # Keywords (weight: 2x) - very distinctive features
        keywords = item.get("keywords", [])
        parts.extend(keywords * 2)
        
        # Cast names (weight: 1x)
        cast = item.get("cast", [])
        cast_names = [c["name"].replace(" ", "_") for c in cast if isinstance(c, dict)]
        parts.extend(cast_names)
        
        # Directors/Creators (weight: 1x)
        directors = item.get("directors", [])
        creators = item.get("creators", [])
        parts.extend([d.replace(" ", "_") for d in directors])
        parts.extend([c.replace(" ", "_") for c in creators])
        
        # Overview words (weight: 1x) - thematic content
        overview = item.get("overview", "")
        if overview:
            # Just add the overview as-is, TF-IDF will tokenize
            parts.append(overview)
        
        # Combine all parts
        return " ".join(parts).lower()

# %%
data[]
# Out:
#      tmdb_id           title   type  year  \
# 0       1396    Breaking Bad     tv  2008
# 1      60625  Rick and Morty     tv  2013
# 2        615        Futurama     tv  1999
# 3       1433   American Dad!     tv  2005
# 4      62741   Kamisama Kiss     tv  2012
# ..       ...             ...    ...   ...
# 705      129   Spirited Away  movie  2001
# 706   503919  The Lighthouse  movie  2019
# 707   359724  Ford v Ferrari  movie  2019
# 708   387426            Okja  movie  2017
# 709   110415     Snowpiercer  movie  2013
#
#                                                 genres  \
# 0                                       [Drama, Crime]
# 1    [Animation, Comedy, Sci-Fi & Fantasy, Action &...
# 2                [Animation, Comedy, Sci-Fi & Fantasy]
# 3                                  [Animation, Comedy]
# 4                [Animation, Comedy, Sci-Fi & Fantasy]
# ..                                                 ...
# 705                       [Animation, Family, Fantasy]
# 706                         [Drama, Fantasy, Thriller]
# 707                           [Drama, Action, History]
# 708                [Adventure, Drama, Science Fiction]
# 709                   [Action, Science Fiction, Drama]
#
#                                               keywords  \
# 0    [new mexico, drug dealer, narcissism, psychopa...
# 1    [time travel, grandfather, alcoholism, alien, ...
# 2    [spacecraft, future, space travel, melancholy,...
# 3    [central intelligence agency (cia), social sat...
# 4    [magic, friendship, supernatural, high school,...
# ..                                                 ...
# 705  [witch, parent child relationship, darkness, b...
# 706  [island, nightmare, isolation, mermaid, halluc...
# 707  [based on novel or book, car race, sports, car...
# 708  [new york city, monster, slaughterhouse, east ...
# 709  [new year's eve, rebellion, cold, parent child...
#
#                                               overview  \
# 0    Walter White, a New Mexico chemistry teacher, ...
# 1    Follows a sociopathic genius scientist who dra...
# 2    The adventures of a late-20th-century New York...
# 3    The series focuses on an eccentric motley crew...
# 4    Nanami was just a normal high school girl down...
# ..                                                 ...
# 705  A young girl, Chihiro, becomes trapped in a st...
# 706  Two lighthouse keepers try to maintain their s...
# 707  American car designer Carroll Shelby and the B...
# 708  A young girl named Mija risks everything to pr...
# 709  In a future where a failed global-warming expe...
#
#                                                tagline  vote_average  \
# 0                                 Change the equation.         8.935
# 1                 Science makes sense, family doesn't.         8.683
# 2                    Defying gravity and common sense.         8.368
# 3    From the creator of "Family Guy" comes a man w...         7.000
# 4                                                              8.600
# ..                                                 ...           ...
# 705           Beyond the tunnel was a mysterious town.         8.500
# 706                           Keeping secrets, are ye?         7.484
# 707            They took the American dream for a ride         8.000
# 708          We needed a miracle. And then we got one.         7.346
# 709                       Fight your way to the front.         6.910
#
#      vote_count  ...                                               cast  \
# 0         16843  ...  [{'name': 'Bryan Cranston', 'popularity': 6.13...
# 1         10587  ...  [{'name': 'Chris Parnell', 'popularity': 2.753...
# 2          3582  ...  [{'name': 'Billy West', 'popularity': 1.7181, ...
# 3          2282  ...  [{'name': 'Seth MacFarlane', 'popularity': 3.4...
# 4           992  ...  [{'name': 'Yui Horie', 'popularity': 2.2087, '...
# ..          ...  ...                                                ...
# 705       17795  ...  [{'name': 'Rumi Hiiragi', 'popularity': 2.1533...
# 706        5360  ...  [{'name': 'Robert Pattinson', 'popularity': 6....
# 707        8673  ...  [{'name': 'Matt Damon', 'popularity': 10.9619,...
# 708        4453  ...  [{'name': 'Ahn Seo-hyun', 'popularity': 1.7392...
# 709       10148  ...  [{'name': 'Chris Evans', 'popularity': 8.7342,...
#
#                                           creators original_language  \
# 0                                 [Vince Gilligan]                en
# 1                     [Dan Harmon, Justin Roiland]                en
# 2                                  [Matt Groening]                en
# 3    [Matt Weitzman, Seth MacFarlane, Mike Barker]                en
# 4                                               []                ja
# ..                                             ...               ...
# 705                                            NaN                ja
# 706                                            NaN                en
# 707                                            NaN                en
# 708                                            NaN                en
# 709                                            NaN                ko
#
#                           poster_path            status number_of_seasons  \
# 0    /ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg             Ended               5.0
# 1     /WGRQ8FpjkDTzivQJ43t94bOuY0.jpg  Returning Series               8.0
# 2    /6ZS8SOno6kTmWz4eQ8lX8EBXOMv.jpg  Returning Series              10.0
# 3    /aC1q422YhQR7k82GB8gW4KoD91p.jpg  Returning Series              22.0
# 4    /5E7GL8KxpFemEFl3Lv8Fu4RuSwa.jpg             Ended               2.0
# ..                                ...               ...               ...
# 705  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg               NaN               NaN
# 706  /f1tIYarTbkBdIT1aW0gzelDwknv.jpg               NaN               NaN
# 707  /dR1Ju50iudrOh3YgfwkAU1g2HZe.jpg               NaN               NaN
# 708  /lHBYG2NcBMW7UpFL4rSCpsgvz4m.jpg               NaN               NaN
# 709  /nzccOvhrLGI0nvAknCEAk8bchD9.jpg               NaN               NaN
#
#                                    recommended_because  \
# 0    [Rick and Morty, Family Guy, Severance, Asia, ...
# 1    [Family Guy, Arcane, Stranger Things, Dexter's...
# 2    [Rick and Morty, Dexter's Laboratory, Family G...
# 3             [Rick and Morty, Family Guy, South Park]
# 4              [Arcane, SPY x FAMILY, Stranger Things]
# ..                                                 ...
# 705                                         [Parasite]
# 706                                         [Parasite]
# 707                                         [Parasite]
# 708                                         [Parasite]
# 709                                         [Parasite]
#
#      recommendation_strength runtime         directors
# 0                          6     NaN               NaN
# 1                          5     NaN               NaN
# 2                          4     NaN               NaN
# 3                          4     NaN               NaN
# 4                          3     NaN               NaN
# ..                       ...     ...               ...
# 705                        1   125.0  [Hayao Miyazaki]
# 706                        1   109.0   [Robert Eggers]
# 707                        1   153.0   [James Mangold]
# 708                        1   120.0    [Bong Joon Ho]
# 709                        1   127.0    [Bong Joon Ho]
#
# [710 rows x 22 columns]

# %%
_build_feature_text(c)
